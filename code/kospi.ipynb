# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/KOSPI.csv")
df.head()
# Out:
#          Date  KOSPI_index   Volume  Transaction_Amount  Market_Cap  \
# 0  2025-05-22      2593.67  35806.0             89655.0  21260119.0
# 1  2025-05-21      2625.58  37153.0             74411.0  21516055.0
# 2  2025-05-20      2601.80  45699.0             76614.0  21335074.0
# 3  2025-05-19      2603.42  31330.0             67524.0  21348538.0
# 4  2025-05-16      2626.87  35971.0             80250.0  21544355.0
#
#    Credit_Balance_KOSPI  Credit_Ratio_to_MarketCap  \
# 0              10383768                   0.488415
# 1              10349223                   0.481000
# 2              10320861                   0.483751
# 3              10314544                   0.483150
# 4              10236751                   0.475148
#
#    Credit_Change_Ratio_to_Transaction
# 0                                 NaN
# 1                           -0.464246
# 2                           -0.370193
# 3                           -0.093552
# 4                           -0.969383

# %%
# 숫자형 열만 추출
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns

# 서브플롯 설정: 한 줄에 2개씩, 전체 변수 수만큼 행 구성
n_cols = 2
n_rows = (len(numeric_cols) + 1) // n_cols

plt.figure(figsize=(12, 4 * n_rows))  # 크기는 행 수에 따라 자동 조정

for i, col in enumerate(numeric_cols, 1):
    plt.subplot(n_rows, n_cols, i)
    data = df[col].dropna()
    plt.hist(data, bins=30, color='skyblue', edgecolor='black')
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
